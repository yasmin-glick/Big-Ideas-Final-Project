# %% [markdown]
# # Pittsburgh Arrest Data

# %% [markdown]
# ## Kathryn's Notebook

# %% [markdown]
# ### The sub-matric I chose is the number of police arrests in different Pittsburgh neighborhoods. I thought this would be good to include when considering the best neightborhoods in Pitt because lots of arrests can mean that the neightborhood is unsafe.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
URL = "https://data.wprdc.org/datastore/dump/e03a89dd-134a-4ee8-a2bd-62c40aeebc6f"
arrest = pd.read_csv(URL)
arrest.head(88334)
# Out:
#          _id       PK       CCR   AGE GENDER RACE           ARRESTTIME  \
# 0          1  1975272  16158872  42.0      F    B  2016-08-24T12:20:00
# 1          2  1974456  16144120  31.0      M    W  2016-08-03T14:55:00
# 2          3  1974466  16144165  63.0      F    B  2016-08-03T16:45:00
# 3          4  1974550  16145257  25.0      F    W  2016-08-05T02:36:00
# 4          5  1974596  16145962  25.0      M    B  2016-08-06T02:00:00
# ...      ...      ...       ...   ...    ...  ...                  ...
# 66480  88276  2064629  23140205  18.0      M    B  2023-11-04T00:49:00
# 66481  88277  2064630  23146375  32.0      M    B  2023-09-14T23:44:00
# 66482  88300  2064640  22025579  58.0      F    B  2022-02-19T20:40:00
# 66483  88333  2064660  14251296  26.0      F    B  2014-12-27T04:30:00
# 66484  88334  2064661  14251296  34.0      M    B  2014-12-27T04:30:00
#
#                                          ARRESTLOCATION  \
# 0             4700 Block Centre AV Pittsburgh, PA 15213
# 1      4200 Block Steubenville PKE Pittsburgh, PA 15205
# 2            900 Block Freeport RD Fox Chapel, PA 15238
# 3           Foreland ST & Cedar AV Pittsburgh, PA 15212
# 4             900 Block Woodlow ST Pittsburgh, PA 15205
# ...                                                 ...
# 66480     6600 Block Frankstown AV Pittsburgh, PA 15206
# 66481        1000 Block Airport BL Pittsburgh, PA 15231
# 66482    2100 Block BROWNSVILLE RD PITTSBURGH, PA 15210
# 66483         2000 Block Eggers ST Pittsburgh, PA 15212
# 66484         2000 Block Eggers ST Pittsburgh, PA 15212
#
#                                                 OFFENSES  \
# 0                                     3929 Retail Theft.
# 1           13(a)(16) Possession of Controlled Substance
# 2                                     3929 Retail Theft.
# 3      5503 Disorderly Conduct. / 5505 Public Drunken...
# 4      2702 Aggravated Assault. / 2705 Recklessy Enda...
# ...                                                  ...
# 66480  2702 Aggravated Assault. / 2705 Recklessy Enda...
# 66481                                 9501 Bench Warrant
# 66482  2701 Simple Assault. / 2706 Terroristic Threat...
# 66483  2701 Simple Assault. / 3304 Criminal Mischief....
# 66484     2701 Simple Assault. / 3304 Criminal Mischief.
#
#                                        INCIDENTLOCATION INCIDENTNEIGHBORHOOD  \
# 0             4700 Block Centre AV Pittsburgh, PA 15213           Bloomfield
# 1      4200 Block Steubenville PKE Pittsburgh, PA 15205         Outside City
# 2            900 Block Freeport RD Fox Chapel, PA 15238             Westwood
# 3           Foreland ST & Cedar AV Pittsburgh, PA 15212       East Allegheny
# 4             900 Block Woodlow ST Pittsburgh, PA 15205      Crafton Heights
# ...                                                 ...                  ...
# 66480                N Murtland ST Pittsburgh, PA 15208       Homewood North
# 66481        1000 Block Airport BL Pittsburgh, PA 15231         Outside City
# 66482    2100 Block Brownsville RD Pittsburgh, PA 15210              Carrick
# 66483         2000 Block Eggers ST Pittsburgh, PA 15212            Troy Hill
# 66484         2000 Block Eggers ST Pittsburgh, PA 15212            Troy Hill
#
#       INCIDENTZONE  INCIDENTTRACT  COUNCIL_DISTRICT  PUBLIC_WORKS_DIVISION  \
# 0                5          804.0               8.0                    2.0
# 1              OSC         5599.0               NaN                    NaN
# 2                5         2811.0               9.0                    2.0
# 3                1         2304.0               1.0                    1.0
# 4                5         2814.0               2.0                    5.0
# ...            ...            ...               ...                    ...
# 66480            3         1302.0               NaN                    NaN
# 66481          OSC         5599.0               NaN                    NaN
# 66482            3         2902.0               4.0                    3.0
# 66483            1         2406.0               NaN                    NaN
# 66484            1         2406.0               NaN                    NaN
#
#                X          Y
# 0     -79.949277  40.452551
# 1     -80.088018  40.440136
# 2     -79.891803  40.486625
# 3     -80.001939  40.454080
# 4     -80.052204  40.445900
# ...          ...        ...
# 66480        NaN        NaN
# 66481 -80.255272  40.496059
# 66482 -79.986524  40.393200
# 66483        NaN        NaN
# 66484        NaN        NaN
#
# [66485 rows x 17 columns]

# %%
arrest.groupby("INCIDENTNEIGHBORHOOD").count().loc[:,"OFFENSES"][:88334]
# Out:
# INCIDENTNEIGHBORHOOD
# Allegheny Center       1244
# Allegheny West          130
# Allentown               947
# Arlington               312
# Arlington Heights       155
#                        ...
# Upper Lawrenceville     189
# West End                290
# West Oakland            325
# Westwood                226
# Windgap                 124
# Name: OFFENSES, Length: 98, dtype: int64

# %% [markdown]
# ##Top 40 Neighborhoods with the MOST arrests

# %%
arrest_series = arrest.groupby("INCIDENTNEIGHBORHOOD").count().loc[:,"OFFENSES"].sort_values(ascending=False)
arrest_series[:40]
# Out:
# INCIDENTNEIGHBORHOOD
# Central Business District    4440
# South Side Flats             3497
# Carrick                      2352
# East Allegheny               2216
# Homewood South               2089
# Homewood North               1969
# East Liberty                 1889
# Marshall-Shadeland           1516
# Bluff                        1502
# Mount Washington             1434
# Hazelwood                    1396
# Brookline                    1390
# Lincoln-Lemington-Belmar     1362
# Knoxville                    1336
# Sheraden                     1285
# Allegheny Center             1244
# Beechview                    1201
# East Hills                   1194
# Brighton Heights             1114
# Perry South                  1057
# Bloomfield                    984
# Shadyside                     971
# Allentown                     947
# Middle Hill                   932
# Larimer                       879
# Central North Side            853
# Crawford-Roberts              839
# North Shore                   814
# Squirrel Hill South           812
# South Side Slopes             801
# Fineview                      796
# Homewood West                 764
# Garfield                      722
# Northview Heights             712
# Spring Hill-City View         711
# Bedford Dwellings             665
# Elliott                       663
# Crafton Heights               601
# Perry North                   587
# Highland Park                 558
# Name: OFFENSES, dtype: int64

# %%
arrest_series[:50].plot.bar()
# Out:
# <Axes: xlabel='INCIDENTNEIGHBORHOOD'>

# %%
arrest_series[:40].plot(kind = 'bar')
plt.xlabel('Number of Arrests')
plt.ylabel('Pitt Neighborhoods')
plt.title('Which Pitt Neighborhood has the most Police Arrests?')
plt.show(arrest_series.plot)

# %%
##Top 40 neighborhoods with the LEAST arrests

# %%
arrest_series2 = arrest.groupby("INCIDENTNEIGHBORHOOD").count().loc[:,"OFFENSES"].sort_values(ascending=True)
arrest_series2[:40]
# Out:
# INCIDENTNEIGHBORHOOD
# Mt. Oliver Neighborhood          2
# Troy Hill-Herrs Island           6
# Mt. Oliver Boro                 18
# Central Northside               23
# Ridgemont                       37
# Regent Square                   37
# New Homestead                   39
# Swisshelm Park                  43
# Chartiers City                  46
# East Carnegie                   48
# St. Clair                       55
# Outside County                  57
# Outside State                   67
# Summer Hill                     76
# Oakwood                         82
# Golden Triangle/Civic Arena     83
# Hays                           120
# Mount Oliver                   124
# Windgap                        124
# Fairywood                      127
# Allegheny West                 130
# Arlington Heights              155
# Polish Hill                    166
# Glen Hazel                     169
# Friendship                     174
# Morningside                    188
# Upper Lawrenceville            189
# Duquesne Heights               191
# Esplen                         200
# Spring Garden                  219
# Stanton Heights                223
# Westwood                       226
# Lincoln Place                  227
# Bon Air                        267
# Lower Lawrenceville            272
# Point Breeze North             289
# Squirrel Hill North            290
# West End                       290
# Banksville                     291
# Terrace Village                297
# Name: OFFENSES, dtype: int64

# %%
arrest_series2[:40].plot(kind = 'bar')
plt.xlabel('Number of Arrests')
plt.ylabel('Pitt Neighborhoods')
plt.title('Which Pitt Neighborhood has the least Police Arrests?')
plt.show(arrest_series2.plot)

# %% [markdown]
# ### Conclusion: Mt. Oliver Neighborhood is the safest out of all Pitt neighborhoods, while Central Business District is the least safe.
